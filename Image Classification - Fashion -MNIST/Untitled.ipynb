# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- ----------
# alabaster                          0.7.12
# altair                             3.1.0
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.7
# anaconda-project                   0.8.2
# apyori                             1.1.2
# asn1crypto                         0.24.0
# astroid                            2.1.0
# astropy                            3.1
# atomicwrites                       1.2.1
# attrs                              18.2.0
# Babel                              2.6.0
# backcall                           0.1.0
# backports.functools-lru-cache      1.5
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# beautifulsoup4                     4.9.1
# bitarray                           0.8.3
# bkcharts                           0.2
# ...

# %%
import numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-d4cdadb62aa7> in <module>
# ----> 1 import numpy
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-38d4b0363d82> in <module>
# ----> 1 import pandas
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install --upgrade ipykernel
# Out:
# Requirement already up-to-date: ipykernel in c:\users\allen varughese\anaconda3\lib\site-packages (5.3.4)
# ...

# %%
import numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-d4cdadb62aa7> in <module>
# ----> 1 import numpy
#
# ModuleNotFoundError: No module named 'numpy'

# %%
# !python3 -m ipykernel install --user
# Out:
# 'python3.8' is not recognized as an internal or external command,
# operable program or batch file.
