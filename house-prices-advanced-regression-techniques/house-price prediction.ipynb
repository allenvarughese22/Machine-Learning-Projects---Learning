# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv("train.csv")

# %%
test_data=pd.read_csv("test.csv")

# %%
test_data.head(2)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      6    2010        WD         Normal
# 1   12500      6    2010        WD         Normal
#
# [2 rows x 80 columns]

# %%
data_conc = pd.concat([train_data,test_data], axis =0)

# %%
data_conc
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
data_conc.to_csv('concatinated.csv')

# %%
train_columns = train_data.columns.values

# %%
test_columns = test_data.columns.values

# %%
train_columns.shape, test_columns.shape
# Out:
# ((81,), (80,))

# %%
type(train_columns)
# Out:
# numpy.ndarray

# %%
# finding the extra column in both train and test cv
#it is found that train csv file  have an extra column with name saleprice
list(set (train_columns) - set (test_columns))
# Out:
# ['SalePrice']

# %%
y_values_train = train_data['SalePrice']

# %%
y_values_train.shape
# Out:
# (1460,)

# %%
X_features_train = train_data.drop(columns=['SalePrice'])

# %%
X_features_train.shape
# Out:
# (1460, 80)

# %%
X_features_train['origin']= 'train_csv'

# %%
X_features_test = test_data

# %%
X_features_test['origin'] = 'test_csv'

# %%
X_features_test.shape, X_features_train.shape
# Out:
# ((1459, 81), (1460, 81))

# %%
Combined_X_features = pd.concat([X_features_train,X_features_test])

# %%
Combined_X_features.tail(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1454         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition    origin
# ...
